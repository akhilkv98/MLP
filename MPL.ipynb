# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer

import tensorflow as tf
from tensorflow import keras

#tf.set_random_seed(42)
#np.random.seed(42)

cancerDataset = load_breast_cancer()

X = cancerDataset.data
y = cancerDataset.target

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify=y, random_state=42)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

sc.fit(X_train)

X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

model_MLP = keras.models.Sequential()
# Hidden layer 
model_MLP.add(keras.layers.Dense(units=5, activation='relu',
input_shape= X_train.shape[1:]))
# Output layer 
model_MLP.add(keras.layers.Dense(units=1, activation='sigmoid'))
# Print the summary of network architecture
model_MLP.summary()

model_MLP.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

model_MLP.fit(x=X_train_std, y=y_train, validation_split=0.1,epochs=50, batch_size=16)

print(test_loss, test_accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 155
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 161
# Trainable params: 161
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 26/26 [==============================] - 0s 8ms/step - loss: 0.6307 - accuracy: 0.6528 - val_loss: 0.5747 - val_accuracy: 0.7826
# Epoch 2/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.8362 - val_loss: 0.4655 - val_accuracy: 0.8478
# Epoch 3/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4164 - accuracy: 0.9022 - val_loss: 0.3983 - val_accuracy: 0.8913
# Epoch 4/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3557 - accuracy: 0.9364 - val_loss: 0.3490 - val_accuracy: 0.8913
# Epoch 5/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3046 - accuracy: 0.9438 - val_loss: 0.3101 - val_accuracy: 0.9130
# Epoch 6/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2655 - accuracy: 0.9511 - val_loss: 0.2806 - val_accuracy: 0.9348
# Epoch 7/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2344 - accuracy: 0.9560 - val_loss: 0.2550 - val_accuracy: 0.9348
# Epoch 8/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2076 - accuracy: 0.9584 - val_loss: 0.2344 - val_accuracy: 0.9348
# Epoch 9/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1895 - accuracy: 0.9633 - val_loss: 0.2160 - val_accuracy: 0.9348
# Epoch 10/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1697 - accuracy: 0.9658 - val_loss: 0.2009 - val_accuracy: 0.9348
# Epoch 11/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1543 - accuracy: 0.9731 - val_loss: 0.1879 - val_accuracy: 0.9565
# Epoch 12/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 0.9780 - val_loss: 0.1774 - val_accuracy: 0.9565
# Epoch 13/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1334 - accuracy: 0.9780 - val_loss: 0.1680 - val_accuracy: 0.9565
# Epoch 14/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1253 - accuracy: 0.9780 - val_loss: 0.1596 - val_accuracy: 0.9565
# Epoch 15/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1190 - accuracy: 0.9804 - val_loss: 0.1532 - val_accuracy: 0.9565
# Epoch 16/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1140 - accuracy: 0.9829 - val_loss: 0.1470 - val_accuracy: 0.9565
# Epoch 17/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1105 - accuracy: 0.9829 - val_loss: 0.1420 - val_accuracy: 0.9565
# Epoch 18/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1033 - accuracy: 0.9829 - val_loss: 0.1374 - val_accuracy: 0.9783
# Epoch 19/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1002 - accuracy: 0.9829 - val_loss: 0.1333 - val_accuracy: 0.9783
# Epoch 20/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0958 - accuracy: 0.9829 - val_loss: 0.1301 - val_accuracy: 0.9783
# Epoch 21/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0933 - accuracy: 0.9829 - val_loss: 0.1264 - val_accuracy: 0.9783
# Epoch 22/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.9829 - val_loss: 0.1231 - val_accuracy: 0.9783
# Epoch 23/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0875 - accuracy: 0.9829 - val_loss: 0.1207 - val_accuracy: 0.9783
# Epoch 24/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0853 - accuracy: 0.9829 - val_loss: 0.1179 - val_accuracy: 0.9783
# Epoch 25/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0910 - accuracy: 0.9829 - val_loss: 0.1148 - val_accuracy: 0.9783
# Epoch 26/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0847 - accuracy: 0.9829 - val_loss: 0.1124 - val_accuracy: 0.9783
# Epoch 27/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.9829 - val_loss: 0.1088 - val_accuracy: 0.9783
# Epoch 28/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9829 - val_loss: 0.1062 - val_accuracy: 0.9783
# Epoch 29/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0752 - accuracy: 0.9829 - val_loss: 0.1044 - val_accuracy: 0.9783
# Epoch 30/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9829 - val_loss: 0.1028 - val_accuracy: 0.9783
# Epoch 31/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0742 - accuracy: 0.9829 - val_loss: 0.1010 - val_accuracy: 0.9783
# Epoch 32/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0721 - accuracy: 0.9829 - val_loss: 0.1006 - val_accuracy: 0.9783
# Epoch 33/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 0.9829 - val_loss: 0.0994 - val_accuracy: 0.9783
# Epoch 34/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0702 - accuracy: 0.9829 - val_loss: 0.0982 - val_accuracy: 0.9783
# Epoch 35/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0687 - accuracy: 0.9829 - val_loss: 0.0967 - val_accuracy: 0.9783
# Epoch 36/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0681 - accuracy: 0.9829 - val_loss: 0.0965 - val_accuracy: 0.9783
# Epoch 37/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0677 - accuracy: 0.9829 - val_loss: 0.0954 - val_accuracy: 0.9783
# Epoch 38/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9829 - val_loss: 0.0953 - val_accuracy: 0.9783
# Epoch 39/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0658 - accuracy: 0.9829 - val_loss: 0.0946 - val_accuracy: 0.9783
# Epoch 40/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9829 - val_loss: 0.0941 - val_accuracy: 0.9783
# Epoch 41/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9829 - val_loss: 0.0927 - val_accuracy: 0.9783
# Epoch 42/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0630 - accuracy: 0.9829 - val_loss: 0.0935 - val_accuracy: 0.9783
# Epoch 43/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9829 - val_loss: 0.0919 - val_accuracy: 0.9783
# Epoch 44/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9829 - val_loss: 0.0919 - val_accuracy: 0.9783
# Epoch 45/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 0.9829 - val_loss: 0.0912 - val_accuracy: 0.9783
# Epoch 46/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 0.9829 - val_loss: 0.0915 - val_accuracy: 0.9783
# Epoch 47/50
# 26/26 [==============================] - 0s 3ms/step - loss: 0.0648 - accuracy: 0.9829 - val_loss: 0.0909 - val_accuracy: 0.9783
# Epoch 48/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 0.9829 - val_loss: 0.0898 - val_accuracy: 0.9783
# Epoch 49/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0586 - accuracy: 0.9829 - val_loss: 0.0890 - val_accuracy: 0.9783
# Epoch 50/50
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0579 - accuracy: 0.9829 - val_loss: 0.0888 - val_accuracy: 0.9783
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5f927252346d> in <module>()
#      40 model_MLP.fit(x=X_train_std, y=y_train, validation_split=0.1,epochs=50, batch_size=16)
#      41
# ---> 42 print(test_loss, test_accuracy)
#
# NameError: name 'test_loss' is not defined
